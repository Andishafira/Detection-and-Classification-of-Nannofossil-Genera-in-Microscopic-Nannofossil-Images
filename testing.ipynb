# %% [markdown]
# #Connect Data

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/MyDrive/REVISI_PENDADARAN'

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 24.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 118.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 39.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# #YOLOv11 X (Adjust Hyperparameter Enhanced Dataset)

# %%
from ultralytics import YOLO
model = YOLO(model="/content/gdrive/MyDrive/REVISI_PENDADARAN/training/training_hyperparam/Yolov11X/runs(trial1)/detect/train/weights/best.pt")

model.val(data="/content/gdrive/MyDrive/REVISI_PENDADARAN/dataset/dataset_enhanced_balanced/data.yaml", split="test")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.152 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11x summary (fused): 190 layers, 56,831,644 parameters, 0 gradients, 194.4 GFLOPs
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 27.6MB/s]
# val: Fast image access ✅ (ping: 0.8±0.8 ms, read: 2.2±1.8 MB/s, size: 1572.8 KB)
# val: Scanning /content/gdrive/MyDrive/REVISI_PENDADARAN/dataset/dataset_enhanced_balanced/test/labels.cache... 292 images, 0 backgrounds, 0 corrupt: 100%|██████████| 292/292 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:36<00:00,  1.94s/it]
# ...

# %% [markdown]
# #YOLOv8 X (Adjust Hyperparameter Enhanced Dataset)

# %%
from ultralytics import YOLO
model = YOLO(model="/content/gdrive/MyDrive/REVISI_PENDADARAN/training/training_hyperparam/Yolov8X/runs/detect/train/weights/best.pt")

model.val(data="/content/gdrive/MyDrive/REVISI_PENDADARAN/dataset/dataset_enhanced_balanced/data.yaml", split="test")
# Out:
# Ultralytics 8.3.141 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11x summary (fused): 190 layers, 56,831,644 parameters, 0 gradients, 194.4 GFLOPs
# WARNING ⚠️ val: Slow image access detected (ping: 10.9±22.7 ms, read: 160.2±152.2 MB/s, size: 1182.2 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /content/gdrive/MyDrive/REVISI_PENDADARAN/dataset/dataset_enhanced_balanced/test/labels.cache... 292 images, 0 backgrounds, 0 corrupt: 100%|██████████| 292/292 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:42<00:00,  2.24s/it]
#                    all        292        515      0.821      0.633      0.702      0.566
#          Coccolith-PPL         73        167      0.823      0.668      0.745      0.624
# ...

# %% [markdown]
# #YOLOv11 X (Balanced Dataset)

# %%
from ultralytics import YOLO
model = YOLO(model="/content/gdrive/MyDrive/REVISI_PENDADARAN/training/training_ukuran_model/YOLOv11X/runs/detect/train/weights/best.pt")

model.val(data="/content/gdrive/MyDrive/REVISI_PENDADARAN/dataset/dataset_enhanced_balanced/data.yaml", split="test")#gantii
# Out:
# Ultralytics 8.3.134 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11x summary (fused): 190 layers, 56,831,644 parameters, 0 gradients, 194.4 GFLOPs
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 83.1MB/s]
# val: Fast image access ✅ (ping: 0.5±0.2 ms, read: 0.9±0.6 MB/s, size: 1436.7 KB)
# val: Scanning /content/gdrive/MyDrive/REVISI_PENDADARAN/dataset/dataset_enhanced_balanced/test/labels.cache... 292 images, 0 backgrounds, 0 corrupt: 100%|██████████| 292/292 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:20<00:00,  1.09s/it]
#                    all        292        515      0.857      0.579      0.649      0.495
#          Coccolith-PPL         73        167      0.828      0.607      0.683      0.536
#          Coccolith-XPL         61        110       0.79       0.58      0.691      0.455
# ...

# %% [markdown]
# #YOLO 11 Enhanced Imbalance Dataset

# %%
from ultralytics import YOLO
model = YOLO(model="/content/gdrive/MyDrive/REVISI_PENDADARAN/training/training_variasi_dataset/data_enhance_imbalance/runs/detect/train2/weights/best.pt")

model.val(data="/content/gdrive/MyDrive/REVISI_PENDADARAN/dataset/dataset_enhance/data.yaml", split="test")
# Out:
# Ultralytics 8.3.141 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 125 layers, 20,033,116 parameters, 0 gradients, 67.7 GFLOPs
# val: Fast image access ✅ (ping: 9.1±19.5 ms, read: 186.3±178.4 MB/s, size: 1200.1 KB)
# val: Scanning /content/gdrive/MyDrive/REVISI_PENDADARAN/dataset/dataset_enhance/test/labels.cache... 292 images, 0 backgrounds, 0 corrupt: 100%|██████████| 292/292 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:14<00:00,  1.34it/s]
#                    all        292        515      0.876      0.581      0.669      0.502
#          Coccolith-PPL         73        167      0.887      0.612      0.711       0.54
#          Coccolith-XPL         61        110      0.832      0.573      0.745      0.488
#         Discoaster-PPL        201        233      0.972       0.94      0.982      0.833
# ...

# %% [markdown]
# #YOLOv11 X (Enhanced Dataset)

# %%
from ultralytics import YOLO
model = YOLO(model="/content/gdrive/MyDrive/REVISI_PENDADARAN/training/training_ukuran_model/YOLOv11X/runs(trial1)/detect/train/weights/best.pt")

model.val(data="/content/gdrive/MyDrive/REVISI_PENDADARAN/dataset/dataset_enhanced_balanced/data.yaml", split="test")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.141 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11x summary (fused): 190 layers, 56,831,644 parameters, 0 gradients, 194.4 GFLOPs
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 95.1MB/s]
# val: Fast image access ✅ (ping: 1.0±0.8 ms, read: 3.2±4.5 MB/s, size: 1422.1 KB)
# val: Scanning /content/gdrive/MyDrive/REVISI_PENDADARAN/dataset/dataset_enhanced_balanced/test/labels.cache... 292 images, 0 backgrounds, 0 corrupt: 100%|██████████| 292/292 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:22<00:00,  1.19s/it]
# ...

# %% [markdown]
# #YOLOv11 L (Enhanced Dataset)

# %%
from ultralytics import YOLO
model = YOLO(model="/content/gdrive/MyDrive/REVISI_PENDADARAN/training/training_ukuran_model/YOLOv11L/runs(trial1)/detect/train2/weights/best.pt")

model.val(data="/content/gdrive/MyDrive/REVISI_PENDADARAN/dataset/dataset_enhanced_balanced/data.yaml", split="test")
# Out:
# Ultralytics 8.3.141 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11l summary (fused): 190 layers, 25,282,396 parameters, 0 gradients, 86.6 GFLOPs
# WARNING ⚠️ val: Slow image access detected (ping: 15.0±32.6 ms, read: 137.5±134.0 MB/s, size: 1483.5 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /content/gdrive/MyDrive/REVISI_PENDADARAN/dataset/dataset_enhanced_balanced/test/labels.cache... 292 images, 0 backgrounds, 0 corrupt: 100%|██████████| 292/292 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:15<00:00,  1.21it/s]
#                    all        292        515      0.804      0.596      0.657      0.499
#          Coccolith-PPL         73        167      0.872      0.623      0.697      0.536
# ...

# %% [markdown]
# #YOLOv11 M (Enhanced Dataset)

# %%
from ultralytics import YOLO
model = YOLO(model="/content/gdrive/MyDrive/REVISI_PENDADARAN/training/training_ukuran_model/YOLOv11M/runs(trial1)/detect/train3/weights/best.pt")

model.val(data="/content/gdrive/MyDrive/REVISI_PENDADARAN/dataset/dataset_enhanced_balanced/data.yaml", split="test")
# Out:
# Ultralytics 8.3.141 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 125 layers, 20,033,116 parameters, 0 gradients, 67.7 GFLOPs
# val: Fast image access ✅ (ping: 0.5±0.2 ms, read: 298.0±66.4 MB/s, size: 1697.1 KB)
# val: Scanning /content/gdrive/MyDrive/REVISI_PENDADARAN/dataset/dataset_enhanced_balanced/test/labels.cache... 292 images, 0 backgrounds, 0 corrupt: 100%|██████████| 292/292 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:14<00:00,  1.30it/s]
#                    all        292        515      0.754      0.585      0.652      0.477
#          Coccolith-PPL         73        167      0.862      0.638      0.684      0.511
#          Coccolith-XPL         61        110      0.802      0.582      0.696      0.431
#         Discoaster-PPL        201        233      0.959      0.918      0.969      0.793
# ...

# %% [markdown]
# #YOLOv11 Original Dataset

# %%
from ultralytics import YOLO
model = YOLO(model="/content/gdrive/MyDrive/REVISI_PENDADARAN/training/training_variasi_dataset/data_original/runs/detect/train/weights/best.pt")

model.val(data="/content/gdrive/MyDrive/REVISI_PENDADARAN/dataset/dataset_enhanced_balanced/data.yaml", split="test")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.134 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11x summary (fused): 190 layers, 56,831,644 parameters, 0 gradients, 194.4 GFLOPs
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 96.3MB/s]
# val: Fast image access ✅ (ping: 0.8±0.8 ms, read: 26.1±55.6 MB/s, size: 1087.7 KB)
# val: Scanning /content/gdrive/MyDrive/REVISI_PENDADARAN/dataset/dataset_enhanced_balanced/test/labels.cache... 292 images, 0 backgrounds, 0 corrupt: 100%|██████████| 292/292 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:17<00:00,  1.09it/s]
# ...
